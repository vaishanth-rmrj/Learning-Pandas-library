# %%
import pandas as pd

# %%
# loading the dataset
df = pd.read_csv('data/literacy_rates_data.csv')
df.head()
# Out:
#    index                     Region      Country  Year    Age  Gender  \
# 0      0  Central and Southern Asia  Afghanistan  2011    15+  female
# 1      1  Central and Southern Asia  Afghanistan  2011    15+    male
# 2      2  Central and Southern Asia  Afghanistan  2011    15+   total
# 3      3  Central and Southern Asia  Afghanistan  2011  15-24  female
# 4      4  Central and Southern Asia  Afghanistan  2011  15-24    male
#
#    Literacy rate
# 0       0.176121
# 1       0.454171
# 2       0.317411
# 3       0.321132
# 4       0.618791

# %%
# setting index to different values
df.set_index('Literacy rate', inplace=True)
df.head()
# Out:
#                index                     Region      Country  Year    Age  \
# Literacy rate
# 0.176121           0  Central and Southern Asia  Afghanistan  2011    15+
# 0.454171           1  Central and Southern Asia  Afghanistan  2011    15+
# 0.317411           2  Central and Southern Asia  Afghanistan  2011    15+
# 0.321132           3  Central and Southern Asia  Afghanistan  2011  15-24
# 0.618791           4  Central and Southern Asia  Afghanistan  2011  15-24
#
#                Gender
# Literacy rate
# 0.176121       female
# 0.454171         male
# 0.317411        total
# 0.321132       female
# 0.618791         male

# %%
#  resetting the index
df.reset_index(inplace=True)
df.head()
# Out:
#    Literacy rate  index                     Region      Country  Year    Age  \
# 0       0.176121      0  Central and Southern Asia  Afghanistan  2011    15+
# 1       0.454171      1  Central and Southern Asia  Afghanistan  2011    15+
# 2       0.317411      2  Central and Southern Asia  Afghanistan  2011    15+
# 3       0.321132      3  Central and Southern Asia  Afghanistan  2011  15-24
# 4       0.618791      4  Central and Southern Asia  Afghanistan  2011  15-24
#
#    Gender
# 0  female
# 1    male
# 2   total
# 3  female
# 4    male

# %%
#  sorting index
df.sort_index(ascending=False)
# Out:
#       Literacy rate  index                     Region      Country  Year  \
# 4954       0.811269   4954         Sub-Saharan Africa     Zimbabwe  2014
# 4953       0.927231   4953         Sub-Saharan Africa     Zimbabwe  2014
# 4952       0.734258   4952         Sub-Saharan Africa     Zimbabwe  2014
# 4951       0.887874   4951         Sub-Saharan Africa     Zimbabwe  2014
# 4950       0.897255   4950         Sub-Saharan Africa     Zimbabwe  2014
# ...             ...    ...                        ...          ...   ...
# 4          0.618791      4  Central and Southern Asia  Afghanistan  2011
# 3          0.321132      3  Central and Southern Asia  Afghanistan  2011
# 2          0.317411      2  Central and Southern Asia  Afghanistan  2011
# 1          0.454171      1  Central and Southern Asia  Afghanistan  2011
# 0          0.176121      0  Central and Southern Asia  Afghanistan  2011
#
#         Age  Gender
# 4954    65+   total
# 4953    65+    male
# 4952    65+  female
# ...
